# %%
import pandas as pd
import numpy as np
import mne

# %%
from features import get_features_from_mne

# %%
simulated_raw=mne.io.read_raw_fif('final_raw_'+'001'+'-raw.fif', preload=True)
new_ica=mne.preprocessing.read_ica('ica_'+'001'+'-ica.fif')
# Out:
# Opening raw data file final_raw_001-raw.fif...
#     Range : 0 ... 598999 =      0.000 ...  1197.998 secs
# Ready.
# Reading 0 ... 598999  =      0.000 ...  1197.998 secs...
# Reading ica_001-ica.fif ...
# Now restoring ICA solution ...
# Ready.

# %%
feature_df = get_features_from_mne(simulated_raw, new_ica)

# %%
feature_df
# Out:
#                K        MEV       SAD       SVD       SED       MIF   CORR_BL  \
# ICA000 -0.958523  54.807986  0.039313  0.003483  0.064134  0.079170  0.004467
# ICA001 -0.670723  14.490025  0.014740 -0.000531  0.026450  0.420004  0.002546
# ICA002 -0.795382  16.245299 -0.040787  0.001551  0.017537  0.175268  0.003958
# ICA003 -0.851550   7.746457  0.002134  0.000029  0.001227  0.073498  0.004462
# ICA004 -0.334716   6.245734 -0.031045  0.001493  0.016758  0.219938  0.003798
# ICA005 -0.611449  10.447266 -0.075401 -0.016170  0.007523  0.016700  0.007247
# ICA006 -0.724380  12.830453 -0.064943 -0.015368  0.021336  0.056375  0.007057
# ICA007 -0.764646   4.384175  0.053122 -0.000183  0.006088  0.082945  0.003977
# ICA008 -0.679083  19.233801 -0.060134  0.014236  0.080720  0.230566  0.003638
# ICA009 -0.798353  19.436139 -0.057456 -0.006065  0.056001  0.022242  0.004768
# ICA010 -0.071196   7.183698  0.117508  0.000935  0.028639  0.032605  0.020214
# ...
